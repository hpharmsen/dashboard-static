# %%
import pandas as pd
import datetime
from configparser import ConfigParser
import json, requests, datetime
from pysimplicate import Simplicate

DATE_FORMAT = '%Y-%m-%d'
# Pandas
pd.options.display.float_format = '{:,.1f}'.format
pd.set_option('display.max_columns', 500)
PANDAS_FILE = '../simplicate_cache/hours.pd'
df = pd.read_pickle(PANDAS_FILE)

df = df.query( 'type=="normal"')
df['turnover'] = df.apply(lambda a: (a['hours']+a['corrections']) * (a['tariff'] if a['tariff'] > 0 else a['service_tariff']), axis=1)
df['turnover'] = df.apply(lambda a: a['turnover']/2 if a['project_number'] == 'TOR-3' else a['turnover'], axis=1)
df['week'] = df.apply(lambda a: datetime.datetime.strptime(a['day'],'%Y-%m-%d').isocalendar()[1], axis=1)
df['month'] = df.apply(lambda a: datetime.datetime.strptime(a['day'],'%Y-%m-%d').month, axis=1)
df['corrections_value'] = df.apply(lambda a: (a['corrections']) * (a['tariff'] if a['tariff'] > 0 else a['service_tariff']), axis=1)

# Simplicate
ini = ConfigParser()
ini.read('../credentials.ini')

subdomain = ini['simplicate']['subdomain']
api_key = ini['simplicate']['api_key']
api_secret = ini['simplicate']['api_secret']

sim = Simplicate(subdomain, api_key, api_secret )

# %%
df[-3:]
# Out:
#               employee     organization  \
# 24103  Vinz Timmermans           Oberon
# 24104  Vinz Timmermans           Oberon
# 24105  Vinz Timmermans  Sprout Money BV
#
#                                      project_id       project_name  \
# 24103  project:21ea648f0c0c31fcfeaad60b7a7437df           Internal
# 24104  project:dac6961c7d699864feaad60b7a7437df       Service Team
# 24105  project:d546df523896bc3afeaad60b7a7437df  Marktgevoel Agile
#
#       project_number                         service  \
# 24103          OBE-1                    Teambuilding
# 24104       SERVIC-1                        Meetings
# 24105         MG2021  Marktgevoel - Augustus 2021
#
#                                      service_id    type  service_tariff  \
# 24103  service:4a12cabaa852fa01d8107a68a60f150e  normal             0.0
# 24104  service:f0b810be8dd3aaddb48628b99c52fe43  normal             0.0
# 24105  service:599b7052835bc71df0d06734914aca76  normal           110.0
#
#                     label  billable  tariff  hours         day      status  \
# 24103            Internal     False     0.0    0.8  2021-08-25  to_forward
# 24104            Internal     False     0.0    0.2  2021-08-25  to_forward
# 24105  Project Management      True    85.0    0.2  2021-08-25  to_forward
#
#        corrections  turnover  week  corrections_value  month
# 24103          0.0       0.0    34                0.0      8
# 24104          0.0       0.0    34                0.0      8
# 24105          0.0      21.2    34                0.0      8

# %% [markdown]
# ## Turnover

# %%
def turnover( project, month=None, from_date=None ):
    query = f'project_number=="{project}"'
    if month: 
        query += f' and month=={month}'
    if from_date:
        query += f' and day>="{from_date}"'
    data = df.query(query)
    return data['turnover'].sum()

turnover( 'BAM-1', from_date='2021-02-01')
# Out:
# 180505.41250000003

# %% [markdown]
# ## Invoices

# %%
def invoiced(project, month=None ):
    filter = {'project_number':project}
    if month:
        filter['from_date'] = f'2021-0{month}-01'
        filter['until_date'] = f'2021-0{month+1}-01'
    invoices = sim.invoice( filter )
    tot = 0
    for invoice in invoices:
        #print( invoice.get('invoice_number','????'), invoice['total_excluding_vat'], invoice['status'])
        tot += invoice['total_excluding_vat']
    return tot

def last_invoice_date( project ):
    invoices = sim.invoice( {'project_number':project} )
    invoices = sorted( invoices, key=lambda i: i['date'])
    if invoices:
        return datetime.datetime.strptime( invoices[-1]['date'], '%Y-%m-%d').date()
    
#print( invoiced( 'BAM-1'))
print( last_invoice_date( 'SLIM-16' ))
# Out:
# 2020-11-30

# %% [markdown]
# ## All projects, certain month

# %%
def active_projects():
    projects = [{'project': project.get('project_number',''),
                 'spent' : project['budget']['hours'].get('value_spent', 0),
                 'invoiced' : project['budget']['total']['value_invoiced']
                }
                for project in sim.project( {'active':True} )]
    return projects
active_projects()[:3]
# Out:
# [{'project': 'BAM-1', 'spent': 207415.6375, 'invoiced': 187204.48},
#  {'project': 'SPIR-3', 'spent': 0, 'invoiced': 1044},
#  {'project': 'WEI-001', 'spent': 0, 'invoiced': 4926.72}]

# %% [markdown]
# ## Onderhanden werk

# %%
pd.set_option('display.max_row', 150)

# project['budget']['total']['value_invoiced']
def corrections(p):
    project = p['project']
    h = df.query( f'project_number=="{project}"' )
    print( 'corrections', project, h['corrections_value'].sum())
    return h['corrections_value'].sum()
    
def onderhanden():
    return pd.DataFrame( [{'project':project['project'], 
                           'spent':project['spent'],
                           'corr': corrections( project),
                           'inv': project['invoiced'],
                           'OH':project['spent'] + corrections( project) - project['invoiced']} 
                          for project in active_projects()] ).sort_values( by=['OH'])
oh = onderhanden()
oh.drop( oh[(oh.project=='TOR-3')].index, inplace=True)
oh
# Out:
# corrections BAM-1 -3662.9625
# corrections BAM-1 -3662.9625
# corrections SPIR-3 0.0
# corrections SPIR-3 0.0
# corrections WEI-001 0.0
# corrections WEI-001 0.0
# corrections VERH-1 -2855.625
# corrections VERH-1 -2855.625
# corrections OBE-1 0.0
# corrections OBE-1 0.0
# corrections THIE-26 0.0
# corrections THIE-26 0.0
# corrections SM2021 85.0
# corrections SM2021 85.0
# corrections MG2021 -6481.25
# corrections MG2021 -6481.25
# corrections NUNOT-1 -3585.0
# corrections NUNOT-1 -3585.0
# corrections SERVIC-1 0.0
# corrections SERVIC-1 0.0
# corrections VJ2021 -2890.0
# corrections VJ2021 -2890.0
# corrections BITF-1 0.0
# corrections BITF-1 0.0
# corrections IDFA-4 -2280.0
# corrections IDFA-4 -2280.0
# corrections EASY-2 -5652.5
# corrections EASY-2 -5652.5
# corrections COL-1 -62.5
# corrections COL-1 -62.5
# corrections AMS-1 -14905.0
# corrections AMS-1 -14905.0
# corrections ADY-1 0.0
# corrections ADY-1 0.0
# corrections BRA-2 0.0
# corrections BRA-2 0.0
# corrections MLA-6 0.0
# corrections MLA-6 0.0
# corrections TOR-3 -14064.375
# corrections TOR-3 -14064.375
# corrections TUI-2 0.0
# corrections TUI-2 0.0
# corrections THAL-1 -6077.5
# corrections THAL-1 -6077.5
# corrections EUR-1 -12160.4999999967
# corrections EUR-1 -12160.4999999967
# corrections CEO-1 -4117.5
# corrections CEO-1 -4117.5
# corrections BEN-1 1030.0
# corrections BEN-1 1030.0
# corrections ACC-1 0.0
# corrections ACC-1 0.0
# corrections BCM-1 -3052.5
# corrections BCM-1 -3052.5
# corrections OBE-3 0.0
# corrections OBE-3 0.0
# corrections CAP-12 0.0
# corrections CAP-12 0.0
# corrections TOMMY-1 -1125.0
# corrections TOMMY-1 -1125.0
# corrections THIE-25 0.0
# corrections THIE-25 0.0
# corrections MANA-1 0.0
# corrections MANA-1 0.0
# corrections BOER-1 -585.0
# corrections BOER-1 -585.0
# corrections SM21 0.0
# corrections SM21 0.0
# corrections MTM-1 0.0
# corrections MTM-1 0.0
# corrections LAND-2 -385.0
# corrections LAND-2 -385.0
# corrections BROE-1 -525.0
# corrections BROE-1 -525.0
# corrections ODC-1 0.0
# corrections ODC-1 0.0
# corrections METR-1 0.0
# corrections METR-1 0.0
# corrections IDFA-1 -5400.0
# corrections IDFA-1 -5400.0
# corrections ONC-1 -1842.5
# corrections ONC-1 -1842.5
# corrections TEX-2 -585.0
# corrections TEX-2 -585.0
# corrections ESCH-1 -8030.0
# corrections ESCH-1 -8030.0
# corrections COMP-1 0.0
# corrections COMP-1 0.0
# corrections GINI 0.0
# corrections GINI 0.0
# corrections OBEN21 0.0
# corrections OBEN21 0.0
# corrections ROCK-4 0.0
# corrections ROCK-4 0.0
# corrections TRAV-1 0.0
# corrections TRAV-1 0.0
# corrections PM-1 -2612.5
# corrections PM-1 -2612.5
# corrections TEX-1 -82164.375
# corrections TEX-1 -82164.375
# corrections SLIM-30 -85.0
# corrections SLIM-30 -85.0
# corrections TMC-1 -3135.0
# corrections TMC-1 -3135.0
# corrections TRAV-4 0.0
# corrections TRAV-4 0.0
# corrections VWF-1 0.0
# corrections VWF-1 0.0
# corrections VWF-2 0.0
# corrections VWF-2 0.0
# corrections CAP-10 0.0
# corrections CAP-10 0.0
# corrections CAP-11 0.0
# corrections CAP-11 0.0
# corrections TRAV-9 0.0
# corrections TRAV-9 0.0
# corrections BELE-1 -412.5
# corrections BELE-1 -412.5
# corrections HAVA-2 -26902.5
# corrections HAVA-2 -26902.5
# corrections VOLK-1 -4974.75
# corrections VOLK-1 -4974.75
# corrections BROE-4 0.0
# corrections BROE-4 0.0
# corrections TOPA-1 -1952.5
# corrections TOPA-1 -1952.5
# corrections TRAV-7 0.0
# corrections TRAV-7 0.0
# corrections TRAV-8 0.0
# corrections TRAV-8 0.0
# corrections IMC-1 0.0
# corrections IMC-1 0.0
# corrections WIND-7 0.0
# corrections WIND-7 0.0
# corrections TRAV-3 0.0
# corrections TRAV-3 0.0
# corrections AME-1 0.0
# corrections AME-1 0.0
# corrections NUTR-1 0.0
# corrections NUTR-1 0.0
# corrections TEST 0.0
# corrections TEST 0.0
# corrections SVHK-1 -192.5
# corrections SVHK-1 -192.5
# corrections MM-1 0.0
# corrections MM-1 0.0
# corrections VBA-2 -1252.75
# corrections VBA-2 -1252.75
# corrections OBE-2 0.0
# corrections OBE-2 0.0
# corrections IVA-1 -55.0
# corrections IVA-1 -55.0
# corrections GREE-6 0.0
# corrections GREE-6 0.0
# corrections TER-1 0.0
# corrections TER-1 0.0
# corrections KCP-1 0.0
# corrections KCP-1 0.0
# corrections KPITO-1 -165.0
# corrections KPITO-1 -165.0
# corrections OER-2 -4460.0
# corrections OER-2 -4460.0
# corrections FUNC-1 -962.5
# corrections FUNC-1 -962.5
# corrections BREI-1 0.0
# corrections BREI-1 0.0
# corrections TRAV-5 0.0
# corrections TRAV-5 0.0
# corrections THIE-21 -141.25
# corrections THIE-21 -141.25
# corrections THIE-24 375.0
# corrections THIE-24 375.0
# corrections ONC-3 -11711.25
# corrections ONC-3 -11711.25
# corrections DREAM-1 0.0
# corrections DREAM-1 0.0
# corrections NORM-01 0.0
# corrections NORM-01 0.0
# corrections THIE-23 -8505.0
# corrections THIE-23 -8505.0
# corrections OER-1 -16557.5
# corrections OER-1 -16557.5
# corrections HOUT-1 0.0
# corrections HOUT-1 0.0
# corrections ALEX-2 0.0
# corrections ALEX-2 0.0
# corrections SLIM-9 0.0
# corrections SLIM-9 0.0
# corrections WIND-6 0.0
# corrections WIND-6 0.0
# corrections SCHI-1 0.0
# corrections SCHI-1 0.0
# corrections CAPI-4 0.0
# corrections CAPI-4 0.0
# corrections HEA-2 0.0
# corrections HEA-2 0.0
# corrections BAM-2 0.0
# corrections BAM-2 0.0
# corrections SINT-3 0.0
# corrections SINT-3 0.0
# corrections SINT-2 0.0
# corrections SINT-2 0.0
# corrections RIN-1 -750.0
# corrections RIN-1 -750.0
# corrections PLUC-1 0.0
# corrections PLUC-1 0.0
# corrections TRAV-6 0.0
# corrections TRAV-6 0.0
# corrections MLA-2 0.0
# corrections MLA-2 0.0
# corrections ONC-2 0.0
# corrections ONC-2 0.0
# corrections WARN-1 -55.0
# corrections WARN-1 -55.0
# corrections APL-001 0.0
# corrections APL-001 0.0
# corrections NLA-1 0.0
# corrections NLA-1 0.0
# corrections PROD-2 0.0
# corrections PROD-2 0.0
# corrections SPIR-1 0.0
# corrections SPIR-1 0.0
# corrections ALDA-13 0.0
# corrections ALDA-13 0.0
# corrections CVA-1 0.0
# corrections CVA-1 0.0
# corrections WORR-2 0.0
# corrections WORR-2 0.0
# corrections WORR-1 0.0
# corrections WORR-1 0.0
# corrections IFLA-4 -660.0
# corrections IFLA-4 -660.0
# corrections WARN-2 0.0
# corrections WARN-2 0.0
# corrections CAPI-2 0.0
# corrections CAPI-2 0.0
# corrections MAMA-1 0.0
# corrections MAMA-1 0.0
# corrections PROD-1 0.0
# corrections PROD-1 0.0
#       project     spent      corr       inv        OH
# 6      SM2021 110,563.8      85.0 142,290.0 -31,641.2
# 83     TRAV-5       0.0       0.0  17,395.0 -17,395.0
# 41      TEX-2   2,617.5    -585.0  18,808.5 -16,776.0
# 59     HAVA-2 107,457.5 -26,902.5  90,227.5  -9,672.5
# 42     ESCH-1  15,050.0  -8,030.0  16,640.0  -9,620.0
# 50    SLIM-30  31,705.0     -85.0  40,800.0  -9,180.0
# 11     BITF-1  11,730.0       0.0  20,537.8  -8,807.8
# 67     TRAV-3       0.0       0.0   7,927.5  -7,927.5
# 63     TRAV-7       0.0       0.0   7,608.0  -7,608.0
# 60     VOLK-1  18,488.2  -4,974.8  21,047.2  -7,533.8
# 64     TRAV-8       0.0       0.0   6,866.0  -6,866.0
# 51      TMC-1  19,415.0  -3,135.0  22,870.0  -6,590.0
# 68      AME-1     247.5       0.0   6,697.5  -6,450.0
# 8     NUNOT-1  18,757.5  -3,585.0  21,570.0  -6,397.5
# 98      BAM-2       0.0       0.0   6,300.0  -6,300.0
# 77      TER-1   1,210.0       0.0   7,470.0  -6,260.0
# 55     CAP-10       0.0       0.0   6,000.0  -6,000.0
# 80      OER-2   7,622.5  -4,460.0   8,922.5  -5,760.0
# 21     THAL-1  19,222.5  -6,077.5  18,297.5  -5,152.5
# 52     TRAV-4       0.0       0.0   5,138.0  -5,138.0
# 32     BOER-1   5,507.5    -585.0   9,992.5  -5,070.0
# 105     ONC-2   5,185.0       0.0  10,200.0  -5,015.0
# 2     WEI-001       0.0       0.0   4,926.7  -4,926.7
# 39     IDFA-1  15,030.0  -5,400.0  14,175.0  -4,545.0
# 84    THIE-21   3,223.8    -141.2   7,282.5  -4,200.0
# 54      VWF-2       0.0       0.0   4,030.0  -4,030.0
# 93     SLIM-9       0.0       0.0   3,755.7  -3,755.7
# 76     GREE-6  11,312.5       0.0  15,000.0  -3,687.5
# 34      MTM-1 103,429.4       0.0 106,998.1  -3,568.8
# 13     EASY-2  12,537.5  -5,652.5  10,200.0  -3,315.0
# 17      BRA-2     690.0       0.0   3,900.0  -3,210.0
# 22      EUR-1  31,886.2 -12,160.5  22,694.2  -2,968.5
# 43     COMP-1       0.0       0.0   2,904.0  -2,904.0
# 58     BELE-1   3,080.0    -412.5   5,547.5  -2,880.0
# 46     ROCK-4   3,527.5       0.0   6,300.0  -2,772.5
# 101     RIN-1   6,875.0    -750.0   8,850.0  -2,725.0
# 116    WARN-2       0.0       0.0   2,520.0  -2,520.0
# 29    TOMMY-1   7,852.5  -1,125.0   8,767.5  -2,040.0
# 18      MLA-6       0.0       0.0   1,980.0  -1,980.0
# 61     BROE-4       0.0       0.0   1,764.0  -1,764.0
# 109    PROD-2       0.0       0.0   1,764.0  -1,764.0
# 94     WIND-6       0.0       0.0   1,764.0  -1,764.0
# 100    SINT-2       0.0       0.0   1,489.0  -1,489.0
# 78      KCP-1       0.0       0.0   1,440.0  -1,440.0
# 79    KPITO-1     467.5    -165.0   1,742.5  -1,440.0
# 82     BREI-1     110.0       0.0   1,550.0  -1,440.0
# 81     FUNC-1   2,777.5    -962.5   3,255.0  -1,440.0
# 40      ONC-1   4,125.0  -1,842.5   3,722.5  -1,440.0
# 75      IVA-1     412.5     -55.0   1,757.5  -1,400.0
# 88    NORM-01       0.0       0.0   1,392.0  -1,392.0
# 26      BCM-1  12,430.0  -3,052.5  10,652.5  -1,275.0
# 95     SCHI-1       0.0       0.0   1,200.0  -1,200.0
# 87    DREAM-1       0.0       0.0   1,200.0  -1,200.0
# 91     HOUT-1       0.0       0.0   1,200.0  -1,200.0
# 33       SM21  17,510.0       0.0  18,700.0  -1,190.0
# 102    PLUC-1   1,540.0       0.0   2,640.0  -1,100.0
# 1      SPIR-3       0.0       0.0   1,044.0  -1,044.0
# 114    WORR-1       0.0       0.0   1,044.0  -1,044.0
# 66     WIND-7   3,327.5       0.0   4,097.5    -770.0
# 62     TOPA-1   4,820.0  -1,952.5   3,587.5    -720.0
# 16      ADY-1  18,550.0       0.0  19,254.2    -704.2
# 53      VWF-1     797.5       0.0   1,330.0    -532.5
# 117    CAPI-2   2,112.5       0.0   2,440.0    -327.5
# 38     METR-1       0.0       0.0     300.0    -300.0
# 97      HEA-2       0.0       0.0     250.0    -250.0
# 115    IFLA-4   3,932.5    -660.0   3,520.0    -247.5
# 107   APL-001       0.0       0.0      81.1     -81.1
# 74      OBE-2       0.0       0.0       0.0       0.0
# 73      VBA-2  11,586.5  -1,252.8  10,333.8       0.0
# 71     SVHK-1     907.5    -192.5     715.0       0.0
# 4       OBE-1       0.0       0.0       0.0       0.0
# 96     CAPI-4     935.0       0.0     935.0       0.0
# 28     CAP-12       0.0       0.0       0.0       0.0
# 85    THIE-24   3,401.2     375.0   3,776.2       0.0
# 90      OER-1  80,985.0 -16,557.5  64,427.5       0.0
# 86      ONC-3  21,680.0 -11,711.2   9,968.8       0.0
# 56     CAP-11       0.0       0.0       0.0       0.0
# 89    THIE-23  67,855.0  -8,505.0  59,350.0       0.0
# 48       PM-1   5,307.5  -2,612.5   2,695.0       0.0
# 47     TRAV-1       0.0       0.0       0.0       0.0
# 69     NUTR-1       0.0       0.0       0.0       0.0
# 72       MM-1      27.5       0.0       0.0      27.5
# 44       GINI     191.2       0.0       0.0     191.2
# 119    PROD-1   1,146.2       0.0     880.0     266.2
# 99     SINT-3   9,386.2       0.0   9,110.0     276.2
# 65      IMC-1   1,582.5       0.0   1,282.5     300.0
# 10     VJ2021  25,372.5  -2,890.0  22,057.5     425.0
# 15      AMS-1  35,502.5 -14,905.0  20,075.0     522.5
# 113    WORR-2   2,331.2       0.0   1,760.0     571.2
# 92     ALEX-2     633.8       0.0       0.0     633.8
# 106    WARN-1  12,666.2     -55.0  11,912.5     698.8
# 104     MLA-2   4,227.5       0.0   3,520.0     707.5
# 31     MANA-1  21,406.2       0.0  20,377.5   1,028.8
# 110    SPIR-1  12,591.2       0.0  11,520.0   1,071.2
# 111   ALDA-13   9,172.5       0.0   8,000.0   1,172.5
# 37      ODC-1  10,952.5       0.0   9,262.5   1,690.0
# 25      ACC-1 222,187.5       0.0 220,482.5   1,705.0
# 118    MAMA-1   1,976.2       0.0       0.0   1,976.2
# 103    TRAV-6   2,040.0       0.0       0.0   2,040.0
# 36     BROE-1   8,865.0    -525.0   6,200.0   2,140.0
# 20      TUI-2   2,325.0       0.0       0.0   2,325.0
# 70       TEST   2,362.5       0.0       0.0   2,362.5
# 24      BEN-1 135,820.6   1,030.0 134,142.4   2,708.2
# 30    THIE-25   2,905.0       0.0       0.0   2,905.0
# 108     NLA-1  12,383.8       0.0   9,080.0   3,303.8
# 12     IDFA-4  21,872.5  -2,280.0  14,341.2   5,251.2
# 45     OBEN21   5,287.5       0.0       0.0   5,287.5
# 35     LAND-2  28,742.5    -385.0  22,910.0   5,447.5
# 5     THIE-26   7,290.0       0.0       0.0   7,290.0
# 3      VERH-1  58,976.9  -2,855.6  47,053.8   9,067.5
# 112     CVA-1  12,392.5       0.0       0.0  12,392.5
# 7      MG2021  60,215.4  -6,481.2  38,526.2  15,207.9
# 0       BAM-1 207,415.6  -3,663.0 187,204.5  16,548.2
# 9    SERVIC-1  17,832.5       0.0       0.0  17,832.5
# 57     TRAV-9  20,043.1       0.0       0.0  20,043.1
# 23      CEO-1  27,595.0  -4,117.5       0.0  23,477.5
# 14      COL-1  27,236.2     -62.5       0.0  27,173.8
# 49      TEX-1 197,236.9 -82,164.4  78,395.0  36,677.5
# 27      OBE-3  47,250.0       0.0       0.0  47,250.0

# %%
oh['OH'].sum()
# Out:
# -3153.343337996688

# %% [markdown]
# # Correcties

# %%
df[-3:]
# Out:
#               employee     organization  \
# 24103  Vinz Timmermans           Oberon
# 24104  Vinz Timmermans           Oberon
# 24105  Vinz Timmermans  Sprout Money BV
#
#                                      project_id       project_name  \
# 24103  project:21ea648f0c0c31fcfeaad60b7a7437df           Internal
# 24104  project:dac6961c7d699864feaad60b7a7437df       Service Team
# 24105  project:d546df523896bc3afeaad60b7a7437df  Marktgevoel Agile
#
#       project_number                         service  \
# 24103          OBE-1                    Teambuilding
# 24104       SERVIC-1                        Meetings
# 24105         MG2021  Marktgevoel - Augustus 2021
#
#                                      service_id    type  service_tariff  \
# 24103  service:4a12cabaa852fa01d8107a68a60f150e  normal             0.0
# 24104  service:f0b810be8dd3aaddb48628b99c52fe43  normal             0.0
# 24105  service:599b7052835bc71df0d06734914aca76  normal           110.0
#
#                     label  billable  tariff  hours         day      status  \
# 24103            Internal     False     0.0    0.8  2021-08-25  to_forward
# 24104            Internal     False     0.0    0.2  2021-08-25  to_forward
# 24105  Project Management      True    85.0    0.2  2021-08-25  to_forward
#
#        corrections  turnover  week  corrections_value  month
# 24103          0.0       0.0    34                0.0      8
# 24104          0.0       0.0    34                0.0      8
# 24105          0.0      21.2    34                0.0      8

# %%
import datetime
one_week_ago = (datetime.datetime.today() + datetime.timedelta(weeks=-1)).strftime(DATE_FORMAT)
five_weeks_ago = (datetime.datetime.today() + datetime.timedelta(weeks=-5)).strftime(DATE_FORMAT)
data = df.query(f'(tariff>0 or service_tariff>0) and day>="{one_week_ago}" and day<"{five_weeks_ago}"')
data
# Out:
# Empty DataFrame
# Columns: [employee, organization, project_id, project_name, project_number, service, service_id, type, service_tariff, label, billable, tariff, hours, day, status, corrections, turnover, week, corrections_value, month]
# Index: []

# %%
df['day'].min()
# Out:
# '2021-01-01'

# %%
one_week_ago = (datetime.datetime.today() + datetime.timedelta(weeks=-1)).strftime(DATE_FORMAT)
five_weeks_ago = (datetime.datetime.today() + datetime.timedelta(weeks=-5)).strftime(DATE_FORMAT)
query = f'(tariff>0 or service_tariff>0) and day>="{five_weeks_ago}" and day<"{one_week_ago}"'
print( query )
data = df.query(query)
print( data['day'].min() )
print( data['day'].max() )
print( data['hours'].sum() )
percentage_corrected = 100 * -data['corrections'].sum() / data['hours'].sum()
percentage_corrected
# Out:
# (tariff>0 or service_tariff>0) and day>="2021-07-21" and day<"2021-08-18"
# 2021-07-21
# 2021-08-17
# 2590.75
# 5.117565698477275

# %%
DATE_FORMAT = '%Y-%m-%d'
lastmonth = (datetime.datetime.today() + datetime.timedelta(days=-30)).strftime(DATE_FORMAT)
a = df.query(f'corrections < 0 and day>="{lastmonth}"').groupby(['organization','project_name']).agg({'hours':'sum','corrections':'sum', 'turnover':'sum'}).sort_values('corrections').query('corrections < -10')
a.reset_index()
# Out:
#       organization       project_name  hours  corrections  turnover
# 0  Sprout Money BV  Marktgevoel Agile   31.5        -31.5       0.0
# 1     De Volksbank     Eurowijs - SLA   15.2        -13.0     222.8

# %% [markdown]
# ## Correcties op een specifiek project

# %%
easy = df.query('project_number == "EASY-1"')
easy
# Out:
#                  employee organization  \
# 569    Sebastian Schipper   EasyBroker
# 694    Sebastian Schipper   EasyBroker
# 991    Sebastian Schipper   EasyBroker
# 1038   Sebastian Schipper   EasyBroker
# 1152   Sebastian Schipper   EasyBroker
# 1184   Sebastian Schipper   EasyBroker
# 1258   Sebastian Schipper   EasyBroker
# 1327   Sebastian Schipper   EasyBroker
# 1340    Joost Cornelissen   EasyBroker
# 1745        Patricia Snel   EasyBroker
# 1746       Sho Stegmeijer   EasyBroker
# 1767   Sebastian Schipper   EasyBroker
# 1816   Sebastian Schipper   EasyBroker
# 1890   Sebastian Schipper   EasyBroker
# 2043   Sebastian Schipper   EasyBroker
# 2047        Patricia Snel   EasyBroker
# 2092   Sebastian Schipper   EasyBroker
# 2391   Sebastian Schipper   EasyBroker
# 2429   Sebastian Schipper   EasyBroker
# 2545       Sho Stegmeijer   EasyBroker
# 2550   Sebastian Schipper   EasyBroker
# 2565        Patricia Snel   EasyBroker
# 2584       Sho Stegmeijer   EasyBroker
# 2606   Sebastian Schipper   EasyBroker
# 2742   Sebastian Schipper   EasyBroker
# 2843   Sebastian Schipper   EasyBroker
# 2860        Patricia Snel   EasyBroker
# 2887   Sebastian Schipper   EasyBroker
# 2893   Sebastian Schipper   EasyBroker
# 2897   Sebastian Schipper   EasyBroker
# 2980   Sebastian Schipper   EasyBroker
# 2988   Sebastian Schipper   EasyBroker
# 2997        Patricia Snel   EasyBroker
# 3018   Sebastian Schipper   EasyBroker
# 3181       Stefan Roovers   EasyBroker
# 3326       Stefan Roovers   EasyBroker
# 3329        Patricia Snel   EasyBroker
# 3630        Patricia Snel   EasyBroker
# 3653   Sebastian Schipper   EasyBroker
# 3775        Patricia Snel   EasyBroker
# 3993        Patricia Snel   EasyBroker
# 4431        Patricia Snel   EasyBroker
# 5774     Bas Colenbrander   EasyBroker
# 5795     Bas Colenbrander   EasyBroker
# 7503     Bas Colenbrander   EasyBroker
# 7631     Bas Colenbrander   EasyBroker
# 7888   Sebastian Schipper   EasyBroker
# 8055       Stefan Roovers   EasyBroker
# 8180       Stefan Roovers   EasyBroker
# 8227     Bas Colenbrander   EasyBroker
# 8231       Stefan Roovers   EasyBroker
# 8495       Stefan Roovers   EasyBroker
# 8625     Bas Colenbrander   EasyBroker
# 8653       Stefan Roovers   EasyBroker
# 8663       Stefan Roovers   EasyBroker
# 8748     Bas Colenbrander   EasyBroker
# 8879       Stefan Roovers   EasyBroker
# 8904       Stefan Roovers   EasyBroker
# 8927       Stefan Roovers   EasyBroker
# 9011       Stefan Roovers   EasyBroker
# 9012     Bas Colenbrander   EasyBroker
# 9167       Stefan Roovers   EasyBroker
# 12050      Stefan Roovers   EasyBroker
#
#                                      project_id      project_name  \
# 569    project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 694    project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 991    project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1038   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1152   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1184   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1258   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1327   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1340   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1745   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1746   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1767   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1816   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 1890   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2043   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2047   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2092   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2391   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2429   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2545   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2550   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2565   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2584   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2606   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2742   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2843   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2860   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2887   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2893   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2897   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2980   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2988   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 2997   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3018   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3181   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3326   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3329   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3630   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3653   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3775   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 3993   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 4431   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 5774   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 5795   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 7503   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 7631   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 7888   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8055   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8180   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8227   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8231   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8495   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8625   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8653   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8663   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8748   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8879   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8904   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 8927   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 9011   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 9012   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 9167   project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
# 12050  project:9b63e1bed41e11eefeaad60b7a7437df  Redesign website
#
#       project_number           service  \
# 569           EASY-1  Redesign website
# 694           EASY-1  Redesign website
# 991           EASY-1  Redesign website
# 1038          EASY-1  Redesign website
# 1152          EASY-1  Redesign website
# 1184          EASY-1  Redesign website
# 1258          EASY-1  Redesign website
# 1327          EASY-1  Redesign website
# 1340          EASY-1  Redesign website
# 1745          EASY-1  Redesign website
# 1746          EASY-1  Redesign website
# 1767          EASY-1  Redesign website
# 1816          EASY-1  Redesign website
# 1890          EASY-1  Redesign website
# 2043          EASY-1  Redesign website
# 2047          EASY-1  Redesign website
# 2092          EASY-1  Redesign website
# 2391          EASY-1  Redesign website
# 2429          EASY-1  Redesign website
# 2545          EASY-1  Redesign website
# 2550          EASY-1  Redesign website
# 2565          EASY-1  Redesign website
# 2584          EASY-1  Redesign website
# 2606          EASY-1  Redesign website
# 2742          EASY-1  Redesign website
# 2843          EASY-1  Redesign website
# 2860          EASY-1  Redesign website
# 2887          EASY-1  Redesign website
# 2893          EASY-1  Redesign website
# 2897          EASY-1  Redesign website
# 2980          EASY-1  Redesign website
# 2988          EASY-1  Redesign website
# 2997          EASY-1  Redesign website
# 3018          EASY-1  Redesign website
# 3181          EASY-1  Redesign website
# 3326          EASY-1  Redesign website
# 3329          EASY-1  Redesign website
# 3630          EASY-1  Redesign website
# 3653          EASY-1  Redesign website
# 3775          EASY-1  Redesign website
# 3993          EASY-1  Redesign website
# 4431          EASY-1  Redesign website
# 5774          EASY-1         Meerwerk
# 5795          EASY-1         Meerwerk
# 7503          EASY-1         Meerwerk
# 7631          EASY-1         Meerwerk
# 7888          EASY-1         Meerwerk
# 8055          EASY-1         Meerwerk
# 8180          EASY-1         Meerwerk
# 8227          EASY-1         Meerwerk
# 8231          EASY-1         Meerwerk
# 8495          EASY-1         Meerwerk
# 8625          EASY-1         Meerwerk
# 8653          EASY-1         Meerwerk
# 8663          EASY-1         Meerwerk
# 8748          EASY-1         Meerwerk
# 8879          EASY-1         Meerwerk
# 8904          EASY-1         Meerwerk
# 8927          EASY-1         Meerwerk
# 9011          EASY-1         Meerwerk
# 9012          EASY-1         Meerwerk
# 9167          EASY-1         Meerwerk
# 12050         EASY-1         Meerwerk
#
#                                      service_id    type  service_tariff  \
# 569    service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 694    service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 991    service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1038   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1152   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1184   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1258   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1327   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 1340   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           125.0
# 1745   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1746   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1767   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 1816   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 1890   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2043   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 2047   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2092   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 2391   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2429   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2545   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2550   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 2565   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2584   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2606   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2742   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2843   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2860   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2887   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2893   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 2897   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 2980   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 2988   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2997   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 3018   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 3181   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 3326   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal           110.0
# 3329   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 3630   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 3653   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 3775   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 3993   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 4431   service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 5774   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 5795   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 7503   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 7631   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 7888   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8055   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8180   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8227   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 8231   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8495   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8625   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 8653   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8663   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8748   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 8879   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8904   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 8927   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 9011   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 9012   service:c863795a0589a342b673c98d2eab4ca5  normal            95.0
# 9167   service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
# 12050  service:c863795a0589a342b673c98d2eab4ca5  normal           110.0
#
#                      label  billable  tariff  hours         day  \
# 569    Product & UX design     False    85.0    1.0  2021-01-07
# 694           UX/UI Design     False    85.0    2.0  2021-01-08
# 991    Product & UX design     False    85.0    2.0  2021-01-12
# 1038   Product & UX design     False    85.0    3.0  2021-01-12
# 1152   Product & UX design     False    85.0    2.0  2021-01-13
# 1184   Product & UX design     False    85.0    3.0  2021-01-13
# 1258   Product & UX design     False    85.0    2.5  2021-01-14
# 1327    Project Management     False    85.0    2.5  2021-01-14
# 1340    Creative Direction     False    85.0    2.0  2021-01-14
# 1745          UX/UI Design     False    85.0    4.0  2021-01-19
# 1746          UX/UI Design     False    85.0    3.0  2021-01-19
# 1767   Product & UX design     False    85.0    3.5  2021-01-19
# 1816    Project Management     False    85.0    0.5  2021-01-19
# 1890   Product & UX design     False    85.0    7.0  2021-01-20
# 2043    Project Management     False    85.0    0.5  2021-01-21
# 2047          UX/UI Design     False    85.0    1.0  2021-01-21
# 2092    Project Management     False    85.0    1.0  2021-01-21
# 2391   Product & UX design     False    85.0    2.0  2021-01-25
# 2429   Product & UX design     False    85.0    3.2  2021-01-25
# 2545   Product & UX design     False    85.0    3.0  2021-01-26
# 2550    Project Management     False    85.0    0.5  2021-01-26
# 2565          UX/UI Design     False    85.0    7.0  2021-01-26
# 2584   Product & UX design     False    85.0    5.0  2021-01-26
# 2606   Product & UX design     False    85.0    2.0  2021-01-26
# 2742   Product & UX design     False    85.0    1.5  2021-01-27
# 2843   Product & UX design     False    85.0    1.5  2021-01-28
# 2860          UX/UI Design     False    85.0    4.0  2021-01-28
# 2887   Product & UX design     False    85.0    1.0  2021-01-28
# 2893    Project Management     False    85.0    1.0  2021-01-28
# 2897    Project Management     False    85.0    0.5  2021-01-28
# 2980    Project Management     False    85.0    0.2  2021-01-29
# 2988   Product & UX design     False    85.0    2.8  2021-01-29
# 2997          UX/UI Design     False    85.0    6.5  2021-01-29
# 3018   Product & UX design     False    85.0    2.0  2021-01-29
# 3181    Project Management     False    85.0    0.2  2021-02-01
# 3326    Project Management     False    85.0    0.5  2021-02-02
# 3329          UX/UI Design     False    85.0    7.0  2021-02-02
# 3630          UX/UI Design     False    85.0    6.5  2021-02-04
# 3653   Product & UX design     False    85.0    4.0  2021-02-04
# 3775          UX/UI Design     False    85.0    6.5  2021-02-05
# 3993          UX/UI Design     False    85.0    4.0  2021-02-08
# 4431          UX/UI Design     False    85.0    7.0  2021-02-11
# 5774          UX/UI Design      True    95.0    3.2  2021-02-24
# 5795          UX/UI Design      True    95.0    3.2  2021-02-24
# 7503          UX/UI Design      True    95.0    1.0  2021-03-11
# 7631          UX/UI Design      True    95.0    1.0  2021-03-12
# 7888    Project Management      True    85.0    1.0  2021-03-16
# 8055    Project Management      True    85.0    0.2  2021-03-17
# 8180    Project Management      True    85.0    0.2  2021-03-18
# 8227          UX/UI Design      True    85.0    0.8  2021-03-18
# 8231    Project Management      True    85.0    1.2  2021-03-18
# 8495    Project Management      True    85.0    0.8  2021-03-22
# 8625          UX/UI Design      True    85.0    8.0  2021-03-23
# 8653    Project Management      True    85.0    0.2  2021-03-23
# 8663    Project Management      True    85.0    0.2  2021-03-23
# 8748          UX/UI Design      True    85.0    2.5  2021-03-24
# 8879    Project Management      True    85.0    0.5  2021-03-25
# 8904    Project Management      True    85.0    0.5  2021-03-25
# 8927    Project Management      True    85.0    0.2  2021-03-25
# 9011    Project Management      True    85.0    0.8  2021-03-26
# 9012          UX/UI Design      True    85.0    3.5  2021-03-26
# 9167    Project Management      True    85.0    0.2  2021-03-29
# 12050   Project Management      True    85.0    1.0  2021-04-26
#
#                         status  corrections  turnover  week  \
# 569    projectmanager_approved          0.0      85.0     1
# 694    projectmanager_approved          0.0     170.0     1
# 991    projectmanager_approved          0.0     170.0     2
# 1038   projectmanager_approved          0.0     255.0     2
# 1152   projectmanager_approved          0.0     170.0     2
# 1184   projectmanager_approved          0.0     255.0     2
# 1258   projectmanager_approved          0.0     212.5     2
# 1327   projectmanager_approved          0.0     212.5     2
# 1340   projectmanager_approved          0.0     170.0     2
# 1745   projectmanager_approved          0.0     340.0     3
# 1746   projectmanager_approved         -3.0       0.0     3
# 1767   projectmanager_approved          0.0     297.5     3
# 1816   projectmanager_approved          0.0      42.5     3
# 1890   projectmanager_approved          0.0     595.0     3
# 2043   projectmanager_approved          0.0      42.5     3
# 2047   projectmanager_approved          0.0      85.0     3
# 2092   projectmanager_approved          0.0      85.0     3
# 2391   projectmanager_approved          0.0     170.0     4
# 2429   projectmanager_approved          0.0     276.2     4
# 2545   projectmanager_approved         -3.0       0.0     4
# 2550   projectmanager_approved          0.0      42.5     4
# 2565   projectmanager_approved          0.0     595.0     4
# 2584   projectmanager_approved         -5.0       0.0     4
# 2606   projectmanager_approved          0.0     170.0     4
# 2742   projectmanager_approved          0.0     127.5     4
# 2843   projectmanager_approved          0.0     127.5     4
# 2860   projectmanager_approved          0.0     340.0     4
# 2887   projectmanager_approved          0.0      85.0     4
# 2893   projectmanager_approved          0.0      85.0     4
# 2897   projectmanager_approved          0.0      42.5     4
# 2980   projectmanager_approved          0.0      21.2     4
# 2988   projectmanager_approved          0.0     233.8     4
# 2997   projectmanager_approved          0.0     552.5     4
# 3018   projectmanager_approved          0.0     170.0     4
# 3181   projectmanager_approved          0.0      21.2     5
# 3326   projectmanager_approved          0.0      42.5     5
# 3329   projectmanager_approved          0.0     595.0     5
# 3630   projectmanager_approved          0.0     552.5     5
# 3653   projectmanager_approved          0.0     340.0     5
# 3775   projectmanager_approved          0.0     552.5     5
# 3993   projectmanager_approved          0.0     340.0     6
# 4431   projectmanager_approved          0.0     595.0     6
# 5774   projectmanager_approved          0.0     308.8     8
# 5795   projectmanager_approved          0.0     308.8     8
# 7503   projectmanager_approved          0.0      95.0    10
# 7631   projectmanager_approved          0.0      95.0    10
# 7888                to_forward          0.0      85.0    11
# 8055   projectmanager_approved          0.0      21.2    11
# 8180   projectmanager_approved          0.0      21.2    11
# 8227   projectmanager_approved          0.0      63.8    11
# 8231   projectmanager_approved          0.0     106.2    11
# 8495   projectmanager_approved          0.0      63.8    12
# 8625   projectmanager_approved          0.0     680.0    12
# 8653   projectmanager_approved          0.0      21.2    12
# 8663   projectmanager_approved          0.0      21.2    12
# 8748   projectmanager_approved          0.0     212.5    12
# 8879   projectmanager_approved          0.0      42.5    12
# 8904   projectmanager_approved          0.0      42.5    12
# 8927   projectmanager_approved          0.0      21.2    12
# 9011   projectmanager_approved          0.0      63.8    12
# 9012   projectmanager_approved          0.0     297.5    12
# 9167   projectmanager_approved          0.0      21.2    13
# 12050  projectmanager_approved          0.0      85.0    17
#
#        corrections_value  month
# 569                  0.0      1
# 694                  0.0      1
# 991                  0.0      1
# 1038                 0.0      1
# 1152                 0.0      1
# 1184                 0.0      1
# 1258                 0.0      1
# 1327                 0.0      1
# 1340                 0.0      1
# 1745                 0.0      1
# 1746              -255.0      1
# 1767                 0.0      1
# 1816                 0.0      1
# 1890                 0.0      1
# 2043                 0.0      1
# 2047                 0.0      1
# 2092                 0.0      1
# 2391                 0.0      1
# 2429                 0.0      1
# 2545              -255.0      1
# 2550                 0.0      1
# 2565                 0.0      1
# 2584              -425.0      1
# 2606                 0.0      1
# 2742                 0.0      1
# 2843                 0.0      1
# 2860                 0.0      1
# 2887                 0.0      1
# 2893                 0.0      1
# 2897                 0.0      1
# 2980                 0.0      1
# 2988                 0.0      1
# 2997                 0.0      1
# 3018                 0.0      1
# 3181                 0.0      2
# 3326                 0.0      2
# 3329                 0.0      2
# 3630                 0.0      2
# 3653                 0.0      2
# 3775                 0.0      2
# 3993                 0.0      2
# 4431                 0.0      2
# 5774                 0.0      2
# 5795                 0.0      2
# 7503                 0.0      3
# 7631                 0.0      3
# 7888                 0.0      3
# 8055                 0.0      3
# 8180                 0.0      3
# 8227                 0.0      3
# 8231                 0.0      3
# 8495                 0.0      3
# 8625                 0.0      3
# 8653                 0.0      3
# 8663                 0.0      3
# 8748                 0.0      3
# 8879                 0.0      3
# 8904                 0.0      3
# 8927                 0.0      3
# 9011                 0.0      3
# 9012                 0.0      3
# 9167                 0.0      3
# 12050                0.0      4

# %%
easy.groupby(['organization','project_name','project_id']).agg({'hours':'sum','corrections':'sum', 'turnover':'sum'}).query('corrections < -10')
# Out:
#                                                                         hours  \
# organization project_name     project_id
# EasyBroker   Redesign website project:9b63e1bed41e11eefeaad60b7a7437df  150.5
#
#                                                                         corrections  \
# organization project_name     project_id
# EasyBroker   Redesign website project:9b63e1bed41e11eefeaad60b7a7437df        -11.0
#
#                                                                         turnover
# organization project_name     project_id
# EasyBroker   Redesign website project:9b63e1bed41e11eefeaad60b7a7437df  11,942.5

# %%
df.query(f'corrections < 0 and project_number == "EASY-1"')\
        .groupby(['organization', 'project_name', 'project_id'])\
        .agg({'hours': 'sum', 'corrections': 'sum'})\
        .sort_values('corrections')\
        .reset_index()
# Out:
#   organization      project_name                                project_id  \
# 0   EasyBroker  Redesign website  project:9b63e1bed41e11eefeaad60b7a7437df
#
#    hours  corrections
# 0   11.0        -11.0

# %%
df.query('corrections < 0').query('project_number == "EASY-1"').groupby(['organization','project_name','project_id']).agg({'hours':'sum','corrections':'sum', 'turnover':'sum'}).query('corrections < -10')
# Out:
#                                                                         hours  \
# organization project_name     project_id
# EasyBroker   Redesign website project:9b63e1bed41e11eefeaad60b7a7437df   11.0
#
#                                                                         corrections  \
# organization project_name     project_id
# EasyBroker   Redesign website project:9b63e1bed41e11eefeaad60b7a7437df        -11.0
#
#                                                                         turnover
# organization project_name     project_id
# EasyBroker   Redesign website project:9b63e1bed41e11eefeaad60b7a7437df       0.0

# %%
df.query('corrections < 0 and project_number == "EASY-1"')
# Out:
#             employee organization                                project_id  \
# 1746  Sho Stegmeijer   EasyBroker  project:9b63e1bed41e11eefeaad60b7a7437df
# 2545  Sho Stegmeijer   EasyBroker  project:9b63e1bed41e11eefeaad60b7a7437df
# 2584  Sho Stegmeijer   EasyBroker  project:9b63e1bed41e11eefeaad60b7a7437df
#
#           project_name project_number           service  \
# 1746  Redesign website         EASY-1  Redesign website
# 2545  Redesign website         EASY-1  Redesign website
# 2584  Redesign website         EASY-1  Redesign website
#
#                                     service_id    type  service_tariff  \
# 1746  service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2545  service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
# 2584  service:f0b810be8dd3aaddb673c98d2eab4ca5  normal            95.0
#
#                     label  billable  tariff  hours         day  \
# 1746         UX/UI Design     False    85.0    3.0  2021-01-19
# 2545  Product & UX design     False    85.0    3.0  2021-01-26
# 2584  Product & UX design     False    85.0    5.0  2021-01-26
#
#                        status  corrections  turnover  week  corrections_value  \
# 1746  projectmanager_approved         -3.0       0.0     3             -255.0
# 2545  projectmanager_approved         -3.0       0.0     4             -255.0
# 2584  projectmanager_approved         -5.0       0.0     4             -425.0
#
#       month
# 1746      1
# 2545      1
# 2584      1

# %% [markdown]
# ## Diensten en omzet per dienst

# %%
services_used = set(df['service_id'])
list(services_used)[:3]
# Out:
# ['service:e2c6d0787f56872ab48628b99c52fe43',
#  'service:9900d01608381b9a12278dc9a55a75e0',
#  'service:599b7052835bc71db48628b99c52fe43']

# %%
projects = sim.to_pandas(sim.project())[['id','organization_name','name']]
project_names = {row['id']:row['name'] for index, row in projects.iterrows()}
project_organizations = {row['id']:row['organization_name'] for index, row in projects.iterrows()}

service_details = sim.to_pandas(sim.service())[['id','name','project_id','status','revenue_group_label']].query(f"id in {tuple(services_used)}")
service_details
# Out:
#                                             id                        name  \
# 5     service:86b392ebfd84615bbf0d1878087571b9             Qikker Internal
# 43    service:10580fb7ced949a2bf0d1878087571b9  Organizational Development
# 172   service:92e189b9acf2a314d8107a68a60f150e             Strippenkaart 2
# 336   service:f8d1fe7ad131e1e2d8107a68a60f150e    Qikker Internal Meetings
# 393   service:1c9ef73885497a58d8107a68a60f150e             Strippenkaart 2
# ...                                        ...                         ...
# 1044  service:935aeb06941672a3b61e8ec4cf9407af   Development Sprint Design
# 1045  service:935aeb06941672a3783d0f4c8b4f4078                Sprint 110
# 1046  service:46b339f1a132a2d0b48628b99c52fe43      Software architectuur
# 1047  service:46b339f1a132a2d0f0d06734914aca76         Development for TLP
# 1049  service:46b339f1a132a2d08ae8092ac3a775c4        Concept en validatie
#
#                                     project_id    status  \
# 5     project:5e920f34c4712abc4c13c77ab857ae53      open
# 43    project:5e920f34c4712abc4c13c77ab857ae53      open
# 172   project:a019caf7728c511a4c13c77ab857ae53      open
# 336   project:5e920f34c4712abc4c13c77ab857ae53      open
# 393   project:69e5c43660917c504c13c77ab857ae53      open
# ...                                        ...       ...
# 1044  project:30cdf17b4485b420feaad60b7a7437df      open
# 1045  project:1675e5dd3dbf6d78feaad60b7a7437df  invoiced
# 1046  project:b4d3ad8257533e1bfeaad60b7a7437df  invoiced
# 1047  project:73e3bddc1e183b9afeaad60b7a7437df      open
# 1049  project:b4d3ad8257533e1bfeaad60b7a7437df      open
#
#           revenue_group_label
# 5                         NaN
# 43                        NaN
# 172             Omzet service
# 336                       NaN
# 393             Omzet service
# ...                       ...
# 1044  Omzet productpropositie
# 1045        Omzet development
# 1046  Omzet productpropositie
# 1047     Omzet teampropositie
# 1049  Omzet productpropositie
#
# [237 rows x 5 columns]

# %%
service_details['client'] = service_details.apply(lambda row:project_organizations[row['project_id']], axis=1)
service_details['project'] = service_details.apply(lambda row:project_names[row['project_id']], axis=1)
service_details
# Out:
#                                             id                        name  \
# 5     service:86b392ebfd84615bbf0d1878087571b9             Qikker Internal
# 43    service:10580fb7ced949a2bf0d1878087571b9  Organizational Development
# 172   service:92e189b9acf2a314d8107a68a60f150e             Strippenkaart 2
# 336   service:f8d1fe7ad131e1e2d8107a68a60f150e    Qikker Internal Meetings
# 393   service:1c9ef73885497a58d8107a68a60f150e             Strippenkaart 2
# ...                                        ...                         ...
# 1044  service:935aeb06941672a3b61e8ec4cf9407af   Development Sprint Design
# 1045  service:935aeb06941672a3783d0f4c8b4f4078                Sprint 110
# 1046  service:46b339f1a132a2d0b48628b99c52fe43      Software architectuur
# 1047  service:46b339f1a132a2d0f0d06734914aca76         Development for TLP
# 1049  service:46b339f1a132a2d08ae8092ac3a775c4        Concept en validatie
#
#                                     project_id    status  \
# 5     project:5e920f34c4712abc4c13c77ab857ae53      open
# 43    project:5e920f34c4712abc4c13c77ab857ae53      open
# 172   project:a019caf7728c511a4c13c77ab857ae53      open
# 336   project:5e920f34c4712abc4c13c77ab857ae53      open
# 393   project:69e5c43660917c504c13c77ab857ae53      open
# ...                                        ...       ...
# 1044  project:30cdf17b4485b420feaad60b7a7437df      open
# 1045  project:1675e5dd3dbf6d78feaad60b7a7437df  invoiced
# 1046  project:b4d3ad8257533e1bfeaad60b7a7437df  invoiced
# 1047  project:73e3bddc1e183b9afeaad60b7a7437df      open
# 1049  project:b4d3ad8257533e1bfeaad60b7a7437df      open
#
#           revenue_group_label                                  project  \
# 5                         NaN                                 Internal
# 43                        NaN                                 Internal
# 172             Omzet service  Fietsenmaker-amsterdam.nl Strippenkaart
# 336                       NaN                                 Internal
# 393             Omzet service             Iris Nijenhuis Strippenkaart
# ...                       ...                                      ...
# 1044  Omzet productpropositie                        Platform overname
# 1045        Omzet development                     Slim Beleggen Agile
# 1046  Omzet productpropositie                             Design fases
# 1047     Omzet teampropositie                                      TLP
# 1049  Omzet productpropositie                             Design fases
#
#                              client
# 5                Qikker Online B.V.
# 43               Qikker Online B.V.
# 172   Alex de Rollende Fietsenmaker
# 336              Qikker Online B.V.
# 393                  Iris Nijenhuis
# ...                             ...
# 1044               Verhuisdieren.nl
# 1045                Sprout Money BV
# 1046                     EasyBroker
# 1047                            TUI
# 1049                     EasyBroker
#
# [237 rows x 7 columns]

# %%
revenue_groups = {row['id']:row['revenue_group_label'] for index, row in service_details.iterrows()}

def calc_revenue_group(row):

    if row['project_name'] in ('Slim Beleggen Agile','Slim Beleggen Agile 2020'):
        return 'Omzet trajecten'
    if row['project_name'].count('Travelbase') or row['project_name'].count('TOR-3'):
        return 'Omzet Travelbase'
    rg = service_details_dict[row['service_id']]
    if rg in ('Omzet development', 'Omzet app development','Omzet website','Omzet comcept en design'):
        return 'Omzet projecten'
    return rg

df['revenue_group'] = df.apply(calc_revenue_group, axis=1)

# %%
df.groupby(['revenue_group'])[['turnover']].sum()
# Out:
#                            turnover
# revenue_group
# Omzet Travelbase           23,210.6
# Omzet concept en design    18,401.2
# Omzet overig                    0.0
# Omzet projecten         1,003,512.9
# Omzet service             304,471.8
# Omzet trajecten           528,093.3

# %%
service_details[service_details['revenue_group_label']=='Omzet service']
# Out:
#                                             id  \
# 172   service:92e189b9acf2a314d8107a68a60f150e
# 393   service:1c9ef73885497a58d8107a68a60f150e
# 414   service:6396eb27cf03043cd8107a68a60f150e
# 476   service:6ee5e6c75959593fd8107a68a60f150e
# 524   service:55647084f3050b86d8107a68a60f150e
# 525   service:798863a14c392243d8107a68a60f150e
# 541   service:b52d5a2351f25fe2d8107a68a60f150e
# 598   service:b6b83699fbe3da58d8107a68a60f150e
# 646   service:578464fb5901cd91d8107a68a60f150e
# 669   service:474ab70c5156a75dd8107a68a60f150e
# 671   service:2a4d1bedf594d624d8107a68a60f150e
# 681   service:757cb43cb1627dd2d8107a68a60f150e
# 682   service:09fc7903f07bf3e1d8107a68a60f150e
# 692   service:ab4f9932eec6f40cd8107a68a60f150e
# 693   service:5ee884f8ad2bb6aed8107a68a60f150e
# 697   service:fbc8f9e563f776e5d8107a68a60f150e
# 699   service:59333dd5cd6278f4d8107a68a60f150e
# 700   service:2a2b86ac00892bf4d8107a68a60f150e
# 702   service:7a35a7fd8b10c01fd8107a68a60f150e
# 711   service:216b7a4a2787fd9cd8107a68a60f150e
# 715   service:2694197a2137ea19d8107a68a60f150e
# 721   service:9c9df07733623094d8107a68a60f150e
# 736   service:15f01958dc1b79dbd8107a68a60f150e
# 742   service:71e2c321f73a0eddd8107a68a60f150e
# 744   service:c98465f29ab17664d8107a68a60f150e
# 747   service:f25ef60dfa26ebbfd8107a68a60f150e
# 748   service:078186cc87165210d8107a68a60f150e
# 750   service:82226bce85d6b7f1d8107a68a60f150e
# 753   service:c96639ac3471704bd8107a68a60f150e
# 756   service:47836380d173f299d8107a68a60f150e
# 758   service:2e346dfc352efb98d8107a68a60f150e
# 761   service:a7eaadac4cec45d1d8107a68a60f150e
# 763   service:15ef8420e743aa9ad8107a68a60f150e
# 765   service:c375480160919bced8107a68a60f150e
# 766   service:4d07157b83994461d8107a68a60f150e
# 768   service:e0b51faf13976db6d8107a68a60f150e
# 769   service:65e0c1467f4831ebd8107a68a60f150e
# 771   service:8f0c54616a72d4aab673c98d2eab4ca5
# 774   service:8f0c54616a72d4aab61e8ec4cf9407af
# 777   service:efb97a904673e2eeb48628b99c52fe43
# 779   service:efb97a904673e2eeb673c98d2eab4ca5
# 786   service:10e2990a9ce9ca2db48628b99c52fe43
# 793   service:10e2990a9ce9ca2d783d0f4c8b4f4078
# 797   service:6e599f61f95cd84ddbbc6eee40e2b5f7
# 799   service:6e599f61f95cd84d12278dc9a55a75e0
# 800   service:51ce1f768676e9d3b48628b99c52fe43
# 805   service:51ce1f768676e9d3b61e8ec4cf9407af
# 813   service:f0b810be8dd3aadd783d0f4c8b4f4078
# 821   service:42401517deb07c15b48628b99c52fe43
# 824   service:42401517deb07c15dbbc6eee40e2b5f7
# 826   service:42401517deb07c15b61e8ec4cf9407af
# 827   service:42401517deb07c15783d0f4c8b4f4078
# 828   service:992dafc7ad13ac68b48628b99c52fe43
# 830   service:992dafc7ad13ac68d250481ad7cc455b
# 831   service:992dafc7ad13ac68dbbc6eee40e2b5f7
# 834   service:b83666ecc97b53b1b48628b99c52fe43
# 839   service:b83666ecc97b53b18ae8092ac3a775c4
# 845   service:50ab9f4d9b0504da827610813b27dd96
# 860   service:c0c8ba1993f7e08612278dc9a55a75e0
# 868   service:1dee6ea1f6f1c57cdbbc6eee40e2b5f7
# 870   service:1dee6ea1f6f1c57cb61e8ec4cf9407af
# 882   service:b104600ec6756244783d0f4c8b4f4078
# 884   service:7124c2bded57c88df0d06734914aca76
# 887   service:7124c2bded57c88ddbbc6eee40e2b5f7
# 891   service:c863795a0589a342b673c98d2eab4ca5
# 898   service:c863795a0589a3428ae8092ac3a775c4
# 902   service:809448b0d2c79f88827610813b27dd96
# 911   service:9900d01608381b9ab61e8ec4cf9407af
# 930   service:e4c6910616508c26b48628b99c52fe43
# 932   service:e4c6910616508c26b673c98d2eab4ca5
# 958   service:e803c8860710294112278dc9a55a75e0
# 964   service:c986e0f7ec30e39fd250481ad7cc455b
# 973   service:e54e3294dbeb897d827610813b27dd96
# 977   service:665ae06794a715c4f0d06734914aca76
# 991   service:7eea09b579ba1869827610813b27dd96
# 1009  service:ee575fdd879b74c0827610813b27dd96
#
#                                              name  \
# 172                               Strippenkaart 2
# 393                               Strippenkaart 2
# 414                               Strippenkaart 2
# 476                               Strippenkaart 3
# 524                          Strippenkaart 1 2020
# 525                               Strippenkaart 1
# 541                               Strippenkaart 2
# 598                               Strippenkaart 6
# 646                           Maintenance Sprints
# 669                               Strippenkaart 6
# 671                               Strippenkaart 1
# 681                               Strippenkaart 8
# 682                               Strippenkaart 1
# 692        Maintenance and Support (nacalculatie)
# 693                              Strippenkaart 10
# 697                               Strippenkaart 1
# 699                       Maintenance and Support
# 700                 Beurssignalen Strippenkaart 6
# 702                               Strippenkaart 3
# 711                              Strippenkaart 10
# 715                               Strippenkaart 7
# 721                                  Service (JM)
# 736                                  Service (JM)
# 742                                 Service Basic
# 744                                 Service Basic
# 747                                  Service Plus
# 748                                 Service Basic
# 750                                  Service Plus
# 753                                Service Custom
# 756                                 Service Basic
# 758                                  Service Plus
# 761                                 Service Basic
# 763                                 Service Basic
# 765                                  Service Plus
# 766                                 Service Basic
# 768                                 Service Basic
# 769                                 Service Basic
# 771                                  Service Plus
# 774                                 Service Basic
# 777                                  Service Plus
# 779                                 Service Basic
# 786                                 Service Basic
# 793                                 Service Basic
# 797                                 Service Basic
# 799               Continuous Improvements Januari
# 800                                 Service Basic
# 805                                 Service Basic
# 813                               Strippenkaart 1
# 821                               Strippenkaart 6
# 824   Setting up Binance portal (strippenkaart 1)
# 826                               Strippenkaart 3
# 827                               Strippenkaart 3
# 828                               Strippenkaart 2
# 830                                 Strippenkaart
# 831                                 Strippenkaart
# 834              Continuous Improvements februari
# 839                  Maintenance and Support 2021
# 845                               Strippenkaart 4
# 860               Strippenkaart Alex en Iris 2021
# 868                                 Strippenkaart
# 870   Maintenance and Support o.b.v. nacalculatie
# 882                 Continuous Improvements maart
# 884                       Maintenance and Support
# 887                             CEO Strippenkaart
# 891                                     Meerwerk
# 898   Maintenance and Support o.b.v. nacalculatie
# 902                 Continuous Improvements april
# 911                      Oberon Engelstalige site
# 930                   Continuous Improvements mei
# 932                  General non development work
# 958                                 Service Basic
# 964   Maintenance and Support o.b.v. nacalculatie
# 973                                      Internal
# 977                                 Service Basic
# 991                                  Service Team
# 1009                                Service Basic
#
#                                     project_id    status revenue_group_label  \
# 172   project:a019caf7728c511a4c13c77ab857ae53      open       Omzet service
# 393   project:69e5c43660917c504c13c77ab857ae53      open       Omzet service
# 414   project:59d2ab132db9f9474c13c77ab857ae53  invoiced       Omzet service
# 476   project:fc5dc3ffdea030554c13c77ab857ae53  invoiced       Omzet service
# 524   project:20915e733ad449a6feaad60b7a7437df  invoiced       Omzet service
# 525   project:a5936e3c2b5e8a37feaad60b7a7437df  invoiced       Omzet service
# 541   project:13174969648b84f04c13c77ab857ae53  invoiced       Omzet service
# 598   project:fa776e37c728faf34c13c77ab857ae53  invoiced       Omzet service
# 646   project:f5f44ee31422fb60feaad60b7a7437df      open       Omzet service
# 669   project:823d5a601f8176d44c13c77ab857ae53  invoiced       Omzet service
# 671   project:b71d933802627bd3feaad60b7a7437df  invoiced       Omzet service
# 681   project:8c9492f7a76737be4c13c77ab857ae53  invoiced       Omzet service
# 682   project:08d91d082bdb1788feaad60b7a7437df  invoiced       Omzet service
# 692   project:438094c18475bd8cfeaad60b7a7437df      open       Omzet service
# 693   project:005b19498332d6b64c13c77ab857ae53  invoiced       Omzet service
# 697   project:3b5b0d3a28863268feaad60b7a7437df  invoiced       Omzet service
# 699   project:63d1870297248546feaad60b7a7437df      open       Omzet service
# 700   project:eaaf06d670760215feaad60b7a7437df  invoiced       Omzet service
# 702   project:5d99a79caa0b6f38feaad60b7a7437df  invoiced       Omzet service
# 711   project:8166d3b4cc16aa654c13c77ab857ae53  invoiced       Omzet service
# 715   project:823d5a601f8176d44c13c77ab857ae53  invoiced       Omzet service
# 721   project:5c27573283b28d55feaad60b7a7437df      open       Omzet service
# 736   project:4537cbc119015126feaad60b7a7437df      open       Omzet service
# 742   project:332706370ce0664efeaad60b7a7437df      open       Omzet service
# 744   project:1acd45487cbedaecfeaad60b7a7437df      open       Omzet service
# 747   project:bfa7bdcd85ebfeb9feaad60b7a7437df      open       Omzet service
# 748   project:609b8b8ee695cc2bfeaad60b7a7437df      open       Omzet service
# 750   project:4b9138e15835cdaafeaad60b7a7437df      open       Omzet service
# 753   project:3ffad4a82e71c0b1feaad60b7a7437df      open       Omzet service
# 756   project:3d5fc28224ef4516feaad60b7a7437df      open       Omzet service
# 758   project:94f5af56e83ce1acfeaad60b7a7437df      open       Omzet service
# 761   project:7b8256d304e0f78afeaad60b7a7437df      open       Omzet service
# 763   project:a6dae4555e9b59a4feaad60b7a7437df      open       Omzet service
# 765   project:11049997072ba807feaad60b7a7437df      open       Omzet service
# 766   project:54c06281155070a7feaad60b7a7437df      open       Omzet service
# 768   project:5b9aa481b594947efeaad60b7a7437df      open       Omzet service
# 769   project:93a4906381f4abf7feaad60b7a7437df      open       Omzet service
# 771   project:ba93213f5de2e6a5feaad60b7a7437df      open       Omzet service
# 774   project:6ee533e0e9b5a9a2feaad60b7a7437df      open       Omzet service
# 777   project:6e0295b631d25503feaad60b7a7437df      open       Omzet service
# 779   project:458f11a60675f774feaad60b7a7437df      open       Omzet service
# 786   project:694d25f9bdc95bdbfeaad60b7a7437df      open       Omzet service
# 793   project:10bf33152781684bfeaad60b7a7437df      open       Omzet service
# 797   project:b3f4f7e167cff85cfeaad60b7a7437df      open       Omzet service
# 799   project:7a08116f1db1652dfeaad60b7a7437df      open       Omzet service
# 800   project:b15b69295a80ffb9feaad60b7a7437df      open       Omzet service
# 805   project:10c4cb19ffc40475feaad60b7a7437df      open       Omzet service
# 813   project:feff4f64e4b54c7bfeaad60b7a7437df  invoiced       Omzet service
# 821   project:2f7e18296dd122cf4c13c77ab857ae53  invoiced       Omzet service
# 824   project:6c7adeccdadb36f4feaad60b7a7437df  invoiced       Omzet service
# 826   project:59d2ab132db9f9474c13c77ab857ae53  invoiced       Omzet service
# 827   project:13174969648b84f04c13c77ab857ae53  invoiced       Omzet service
# 828   project:08d91d082bdb1788feaad60b7a7437df  invoiced       Omzet service
# 830   project:fe1ba2b694ccfabffeaad60b7a7437df      open       Omzet service
# 831   project:73d74c80c586e9a14c13c77ab857ae53  invoiced       Omzet service
# 834   project:7a08116f1db1652dfeaad60b7a7437df      open       Omzet service
# 839   project:a4d741eeee7ec054feaad60b7a7437df      open       Omzet service
# 845   project:fc5dc3ffdea030554c13c77ab857ae53  invoiced       Omzet service
# 860   project:3547a32f391eae72feaad60b7a7437df      open       Omzet service
# 868   project:2e7d1588e87a48a8feaad60b7a7437df      open       Omzet service
# 870   project:005b19498332d6b64c13c77ab857ae53      open       Omzet service
# 882   project:7a08116f1db1652dfeaad60b7a7437df      open       Omzet service
# 884   project:a5b8f627ffb1b119feaad60b7a7437df      open       Omzet service
# 887   project:6e0295b631d25503feaad60b7a7437df      open       Omzet service
# 891   project:9b63e1bed41e11eefeaad60b7a7437df      open       Omzet service
# 898   project:8c9492f7a76737be4c13c77ab857ae53      open       Omzet service
# 902   project:7a08116f1db1652dfeaad60b7a7437df      open       Omzet service
# 911   project:8ab4cd734a8bc76dfeaad60b7a7437df      open       Omzet service
# 930   project:7a08116f1db1652dfeaad60b7a7437df      open       Omzet service
# 932   project:3b52aab6e5d8453dfeaad60b7a7437df      open       Omzet service
# 958   project:28a5b954d6036a44feaad60b7a7437df      open       Omzet service
# 964   project:2f7e18296dd122cf4c13c77ab857ae53      open       Omzet service
# 973   project:86a1d06fa68bf747feaad60b7a7437df      open       Omzet service
# 977   project:6c438f3a9abac41bfeaad60b7a7437df      open       Omzet service
# 991   project:1b594af55d20b05bfeaad60b7a7437df      open       Omzet service
# 1009  project:bfa7bdcd85ebfeb9feaad60b7a7437df      open       Omzet service
#
#                                                 project  \
# 172             Fietsenmaker-amsterdam.nl Strippenkaart
# 393                        Iris Nijenhuis Strippenkaart
# 414                      Worrell & Jetten Strippenkaart
# 476                                 JobOn Strippenkaart
# 524                          ALDA General Strippenkaart
# 525                          Maintenance & Support 2020
# 541                 MLA Strippenkaart Montessori Lyceum
# 598                                 Qpido Strippenkaart
# 646                                      Growth Sprints
# 669                             Kunsten92 Strippenkaart
# 671   Finance on a Mission & Transformation Forums S...
# 681                       Maestro Maintenance & Support
# 682                                Needle Strippenkaart
# 692                          Windcentrale Strippenkaart
# 693                         Onderhoud Management Drives
# 697                               ROI Asset Management
# 699                                   CopyCoin M&S 2020
# 700                         Beurssignalen Strippenkaart
# 702                Sint in Amsterdam SiA Strippenkaart
# 711                                   NLA Strippenkaart
# 715                             Kunsten92 Strippenkaart
# 721                                      Eurowijs - SLA
# 736                                     Volksbank - SLA
# 742                                        Oncode - SLA
# 744                                      BCM Tool - SLA
# 747                             MyLosbergerDeBoer - SLA
# 748                                   Functionals - SLA
# 750                                          IDFA - SLA
# 753                                           IMC - SLA
# 756                                         Kpito - SLA
# 758                                   NuNotariaat - SLA
# 761                                        Thales - SLA
# 763                                           TMC - SLA
# 765                                         Tommy - SLA
# 766                                         Oerol - SLA
# 768                                      Van Esch - SLA
# 769                                   VVV Ameland - SLA
# 771                                     VVV Texel - SLA
# 774                                      De Breij - SLA
# 777                                       CEO App - SLA
# 779                                          Topa - SLA
# 786                                  BeleefRoutes - SLA
# 793                                           IVA - SLA
# 797                                          AMS-IX SLA
# 799          Examenbundel onderhoud en doorontwikkeling
# 800                                           TOR - SLA
# 805                                          SVHK - SLA
# 813                         Beurssignalen Strippenkaart
# 821                             Land Life Strippenkaart
# 824                                   BitFirst Exchange
# 826                      Worrell & Jetten Strippenkaart
# 827                 MLA Strippenkaart Montessori Lyceum
# 828                                Needle Strippenkaart
# 830                         Travelbase - Eerste release
# 831                          Orangedotcom Strippenkaart
# 834          Examenbundel onderhoud en doorontwikkeling
# 839                                   CopyCoin M&S 2021
# 845                                 JobOn Strippenkaart
# 860                                   Alex en Iris 2021
# 868                                             Website
# 870                         Onderhoud Management Drives
# 882          Examenbundel onderhoud en doorontwikkeling
# 884                                 Menicon Maintenance
# 887                                       CEO App - SLA
# 891                                    Redesign website
# 898                       Maestro Maintenance & Support
# 902          Examenbundel onderhoud en doorontwikkeling
# 911                                 Oberon - Website EN
# 930          Examenbundel onderhoud en doorontwikkeling
# 932                                  Travelbase running
# 958                                 Pure Matching - SLA
# 964                             Land Life Strippenkaart
# 973                            Oberon - Website Service
# 977                                 Maestro Music - SLA
# 991                                                 SLA
# 1009                            MyLosbergerDeBoer - SLA
#
#                                                  client
# 172                       Alex de Rollende Fietsenmaker
# 393                                      Iris Nijenhuis
# 414   Worrell & Jetten Accountants en Adviseurs Zoet...
# 476                                     Stichting JobOn
# 524                                 Alda Nederland B.V.
# 525                                         Greenchoice
# 541                         Montessori Lyceum Amsterdam
# 598                                             Levvel
# 646                                 Chickslovefood B.V.
# 669                                           Kunsten92
# 671                                           Pluc B.V.
# 681                           Warner Music Benelux B.V.
# 682                                           iFlavours
# 692                                 de Windcentrale B.V
# 693                        Management Drives Holding BV
# 697                               ROI Asset Management
# 699                                     Sprout Money BV
# 700                                     Sprout Money BV
# 702             Stichting Sinterklaas Intocht Amsterdam
# 711                             Next Level Academy B.V.
# 715                                           Kunsten92
# 721                                        De Volksbank
# 736                                        De Volksbank
# 742                                              Oncode
# 744                                     Centraal Beheer
# 747                      Losberger De Boer Holding GmbH
# 748                                         Functionals
# 750                                                IDFA
# 753                                                 IMC
# 756                             AndersWinst Italia srl
# 758                                         NuNotariaat
# 761                               Thales Nederland B.V.
# 763                                                 TMC
# 765                            Tommy Hilfiger Europe BV
# 766                                               Oerol
# 768                                            Van Esch
# 769                                         VVV Ameland
# 771                                           VVV Texel
# 774                                            De Breij
# 777                           T-Mobile Netherlands B.V.
# 779                                        TOPA Thermal
# 786                                        BeleefRoutes
# 793                                      IVA driebergen
# 797                     Amsterdam Internet Exchange BV.
# 799                               ThiemeMeulenhoff B.V.
# 800                                    VVV Terschelling
# 805                              Stichting van het Kind
# 813                                     Sprout Money BV
# 821                              Land Life Company B.V.
# 824                                     Sprout Money BV
# 826   Worrell & Jetten Accountants en Adviseurs Zoet...
# 827                         Montessori Lyceum Amsterdam
# 828                                           iFlavours
# 830                         VVV Waterland van Friesland
# 831                                   Orangedotcom B.V.
# 834                               ThiemeMeulenhoff B.V.
# 839                                     Sprout Money BV
# 845                                     Stichting JobOn
# 860                       Alex de Rollende Fietsenmaker
# 868                                           VVV Texel
# 870                        Management Drives Holding BV
# 882                               ThiemeMeulenhoff B.V.
# 884                                            Capitola
# 887                           T-Mobile Netherlands B.V.
# 891                                          EasyBroker
# 898                           Warner Music Benelux B.V.
# 902                               ThiemeMeulenhoff B.V.
# 911                                              Oberon
# 930                               ThiemeMeulenhoff B.V.
# 932                                          Travelbase
# 958                                       Pure Matching
# 964                              Land Life Company B.V.
# 973                                              Oberon
# 977                           Warner Music Benelux B.V.
# 991                       De Brauw Blackstone Westbroek
# 1009                     Losberger De Boer Holding GmbH

# %% [markdown]
# # Volgende stap: omzet uit diensten waar geen uren voor zijn gemaakt zoals hosting en onderhuur ook toevoegen. Via Facturen?
